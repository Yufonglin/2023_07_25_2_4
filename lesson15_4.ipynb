# %%
import numpy as np
import pandas as pd
student = np.array([67,78,92,74,65])   #-->只有索引，沒有key值。
student
# Series ==>就是類似ndArray，多了key的索引(kei-index)
# DataFrame

# %%
import pandas as pd

s1 = pd.Series([67,78,92,74,65],index=["國文","英文","數學","地理","歷史"])

# %%
s1+3
s1["國文"] #使用key-index
#s1[0] #使用原生的index

# %%
for i in s1:
    print(i)

# %%
#numpy的統計，可以套用在pandas中
s1

# %%
#利用numpy的funation做統計
np.sum(s1)

# %%
np.mean(s1)

# %%
np.std(s1)

# %%
np.median(s1)

# %%
#多個Series組成表格資料-->DataFrame
s1 = pd.DataFrame({
    "林鈺峰":[78,92,76,91,72],
    "林峰":[78,2,76,100,72],
    "x峰":[78,2,76,70,72]}
             ,index=["國文","英文","數學","地理","歷史"])

# %%
import numpy as np
import pandas as pd
data = np.random.randint(60,high=100,size=(50,5))
pd.DataFrame(data,
             index=range(1,51),
             columns=["國文","英文","數學","地理","歷史"])
# Out:
#     國文  英文  數學  地理  歷史
# 1   95  60  80  73  71
# 2   71  71  80  73  90
# 3   77  87  83  92  94
# 4   83  89  87  87  71
# 5   76  71  89  94  88
# 6   81  98  70  93  94
# 7   82  85  69  86  96
# 8   66  98  95  73  63
# 9   76  97  64  66  70
# 10  87  92  83  84  72
# 11  67  92  69  81  67
# 12  80  92  97  88  86
# 13  78  75  76  78  95
# 14  73  82  82  90  99
# 15  78  94  71  69  87
# 16  74  89  90  91  80
# 17  62  99  61  61  92
# 18  61  89  74  62  69
# 19  62  78  71  66  90
# 20  60  71  76  92  76
# 21  73  67  87  84  95
# 22  70  95  97  74  76
# 23  80  79  73  61  71
# 24  69  85  97  64  85
# 25  72  67  73  99  61
# 26  69  66  99  73  60
# 27  67  96  62  70  92
# 28  86  85  68  91  67
# 29  90  62  96  83  91
# 30  69  62  70  78  79
# 31  75  84  79  76  99
# 32  74  73  84  67  79
# 33  80  67  62  98  76
# 34  63  97  84  68  85
# 35  65  74  64  70  77
# 36  66  72  90  69  73
# 37  66  97  73  77  77
# 38  79  68  94  99  85
# 39  74  68  85  64  83
# 40  65  62  84  69  84
# 41  92  95  70  83  89
# 42  95  96  62  60  72
# 43  84  88  69  86  86
# 44  85  92  74  72  61
# 45  98  82  80  91  93
# 46  90  90  91  86  92
# 47  76  81  82  83  71
# 48  95  94  95  64  96
# 49  82  64  85  95  65
# 50  90  98  90  88  72
