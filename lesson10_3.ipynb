# %%
import random
def get_score() -> list:
    score = []
    for i in range(5):
        score.append(random.randint(50, 100))
    return score

students = []
for i in range(50):
    scores = get_score()
    students.append(scores)
students
# Out:
# [[88, 76, 54, 77, 65],
#  [89, 89, 84, 53, 86],
#  [57, 58, 59, 60, 55],
#  [58, 81, 72, 61, 76],
#  [61, 56, 98, 50, 81],
#  [60, 54, 59, 61, 86],
#  [98, 76, 72, 74, 94],
#  [77, 92, 68, 100, 98],
#  [57, 63, 57, 54, 63],
#  [77, 62, 51, 93, 83],
#  [86, 67, 100, 66, 70],
#  [97, 75, 95, 50, 87],
#  [90, 80, 58, 68, 68],
#  [94, 69, 88, 63, 97],
#  [55, 94, 97, 56, 87],
#  [92, 78, 82, 58, 87],
#  [63, 93, 98, 69, 52],
#  [75, 99, 65, 78, 60],
#  [58, 74, 98, 64, 64],
#  [91, 73, 83, 79, 73],
#  [87, 93, 78, 68, 89],
#  [70, 78, 62, 68, 68],
#  [66, 74, 92, 76, 58],
#  [90, 69, 76, 92, 73],
#  [90, 99, 100, 66, 81],
#  [93, 58, 93, 88, 100],
#  [69, 95, 73, 69, 62],
#  [71, 99, 52, 54, 54],
#  [63, 61, 74, 62, 100],
#  [89, 74, 64, 70, 73],
#  [93, 96, 86, 59, 82],
#  [66, 64, 50, 53, 62],
#  [91, 69, 97, 56, 73],
#  [65, 99, 52, 50, 55],
#  [55, 55, 74, 100, 97],
#  [82, 96, 99, 100, 70],
#  [50, 73, 59, 80, 78],
#  [55, 94, 94, 80, 59],
#  [83, 85, 82, 72, 84],
# ...
