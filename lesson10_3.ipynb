# %%
import random
def get_score() -> list:
    score = []
    for i in range(5):
        score.append(random.randint(50, 100))
    return score

students = []
for i in range(50):
    scores = get_score()
    students.append(scores)
students
# Out:
# [[65, 76, 68, 54, 79],
#  [84, 55, 66, 90, 89],
#  [70, 94, 59, 80, 90],
#  [94, 72, 97, 54, 59],
#  [58, 89, 70, 81, 59],
#  [52, 93, 84, 100, 95],
#  [85, 80, 58, 68, 77],
#  [63, 91, 82, 83, 81],
#  [69, 79, 79, 99, 93],
#  [52, 76, 70, 97, 54],
#  [67, 86, 83, 51, 97],
#  [70, 64, 73, 59, 70],
#  [60, 97, 79, 71, 98],
#  [54, 61, 60, 97, 51],
#  [77, 72, 70, 72, 54],
#  [99, 91, 65, 65, 58],
#  [95, 54, 80, 51, 79],
#  [61, 51, 51, 82, 54],
#  [98, 90, 73, 87, 68],
#  [60, 88, 92, 73, 71],
#  [66, 76, 54, 89, 81],
#  [99, 83, 73, 64, 98],
#  [55, 100, 50, 99, 90],
#  [88, 92, 69, 54, 56],
#  [63, 57, 71, 73, 79],
#  [96, 86, 73, 73, 93],
#  [55, 64, 83, 70, 73],
#  [52, 87, 70, 83, 83],
#  [58, 58, 83, 64, 78],
#  [88, 100, 61, 85, 93],
#  [56, 54, 73, 62, 82],
#  [97, 92, 69, 77, 84],
#  [85, 83, 72, 91, 79],
#  [52, 69, 64, 58, 89],
#  [79, 60, 75, 81, 95],
#  [50, 55, 71, 74, 92],
#  [54, 66, 97, 72, 97],
#  [55, 64, 61, 70, 70],
#  [63, 95, 62, 54, 91],
# ...
