# %%
import random
def get_score() -> list:
    score = []
    for i in range(5):
        score.append(random.randint(50, 100))
    return score

def get_names(nums:int) -> list:
    with open('names.txt',encoding='utf-8',newline='') as file:
        names_str = file.read()
        all_names_list = names_str.split(sep="\n")
        names_list = random.choices(all_names_list,k=nums) #取出一定數量的姓名
    return names_list

nums_int = int(input("請輸入學生數:"))
#取得nums_int個姓名
names_list = get_names(nums_int)
students = []
for i in range(nums_int):
    scores = get_score()
    new_list = [names_list[i]] + scores
    students.append(new_list)
students
# Out:
# [['余丞苓', 98, 87, 92, 71, 83],
#  ['潘俊賢', 63, 97, 66, 96, 80],
#  ['賴昌韻', 83, 54, 73, 92, 93],
#  ['梁柏宇', 50, 63, 61, 100, 96],
#  ['謝哲維', 82, 99, 67, 61, 82],
#  ['周怡啟', 80, 76, 71, 64, 57],
#  ['馮芳如', 71, 82, 59, 85, 76],
#  ['王雅慧', 63, 67, 78, 74, 98],
#  ['馬彥文', 99, 80, 91, 81, 74],
#  ['潘俊賢', 92, 81, 66, 83, 76],
#  ['劉佳佩', 77, 76, 55, 74, 76],
#  ['潘英迪', 59, 67, 72, 77, 68],
#  ['張雅芬', 90, 75, 97, 79, 84],
#  ['陳凱翔', 79, 92, 85, 50, 55],
#  ['黃佩芬', 71, 60, 54, 76, 93],
#  ['陳得映', 84, 97, 82, 97, 61],
#  ['張凱妮', 73, 100, 71, 92, 56],
#  ['高智超', 63, 79, 73, 81, 86],
#  ['鞠冠宇', 74, 94, 94, 66, 96],
#  ['黃淑芬', 66, 79, 75, 89, 96],
#  ['張婕妤', 90, 56, 80, 56, 85],
#  ['蘇凡菁', 51, 62, 99, 71, 78],
#  ['賴苑禾', 68, 54, 78, 87, 91],
#  ['馮芳如', 62, 55, 80, 59, 93],
#  ['余宗儒', 90, 55, 83, 97, 68],
#  ['林思賢', 91, 67, 77, 98, 51],
#  ['謝南慧', 90, 59, 90, 75, 58],
#  ['王人仰', 55, 68, 69, 75, 65],
#  ['王展人', 100, 83, 77, 67, 78],
#  ['林佳蓉', 61, 51, 74, 62, 100],
#  ['孫火清', 83, 79, 96, 73, 60],
#  ['李佳彥', 94, 61, 76, 99, 55],
#  ['李彥伸', 87, 88, 73, 86, 64],
#  ['張軒宸', 75, 58, 84, 97, 63],
#  ['吳欣書', 100, 81, 79, 78, 78],
#  ['蔡嘉音', 62, 97, 58, 62, 53],
#  ['黃偉剛', 81, 88, 80, 76, 100],
#  ['林俊翔', 81, 51, 59, 72, 74],
#  ['錢欣潔', 86, 59, 66, 93, 56],
#  ['楊火帆', 63, 75, 58, 82, 52],
#  ['簡佳樺', 65, 81, 92, 57, 98],
#  ['黃奎紹', 77, 89, 69, 66, 81],
#  ['李佳彥', 67, 80, 93, 55, 53],
#  ['張彥博', 77, 63, 99, 58, 80],
#  ['林希啟', 52, 61, 68, 53, 61],
#  ['林向鈺', 82, 50, 95, 94, 93],
#  ['張天亨', 92, 80, 61, 54, 81],
#  ['洪阿惠', 97, 65, 84, 55, 75],
#  ['劉耿琦', 57, 59, 73, 72, 53],
#  ['賴又琦', 74, 89, 89, 72, 79]]

# %%
import pandas as pd

students_df = pd.DataFrame(students,columns=['姓名','國文','英文','數學','地理','歷史'],index=range(1,nums_int+1))
students_df

# %%
students_df.head(n=8)
# Out:
#     姓名  國文  英文  數學   地理  歷史
# 1  余丞苓  98  87  92   71  83
# 2  潘俊賢  63  97  66   96  80
# 3  賴昌韻  83  54  73   92  93
# 4  梁柏宇  50  63  61  100  96
# 5  謝哲維  82  99  67   61  82
# 6  周怡啟  80  76  71   64  57
# 7  馮芳如  71  82  59   85  76
# 8  王雅慧  63  67  78   74  98

# %%
students_df.tail(n=8)
# Out:
#      姓名  國文  英文  數學  地理  歷史
# 43  李佳彥  67  80  93  55  53
# 44  張彥博  77  63  99  58  80
# 45  林希啟  52  61  68  53  61
# 46  林向鈺  82  50  95  94  93
# 47  張天亨  92  80  61  54  81
# 48  洪阿惠  97  65  84  55  75
# 49  劉耿琦  57  59  73  72  53
# 50  賴又琦  74  89  89  72  79

# %%
students_df.index.name ="學號"
students_df.columns.name="科目"
students_df
# Out:
# 科目   姓名   國文   英文  數學   地理   歷史
# 學號
# 1   余丞苓   98   87  92   71   83
# 2   潘俊賢   63   97  66   96   80
# 3   賴昌韻   83   54  73   92   93
# 4   梁柏宇   50   63  61  100   96
# 5   謝哲維   82   99  67   61   82
# 6   周怡啟   80   76  71   64   57
# 7   馮芳如   71   82  59   85   76
# 8   王雅慧   63   67  78   74   98
# 9   馬彥文   99   80  91   81   74
# 10  潘俊賢   92   81  66   83   76
# 11  劉佳佩   77   76  55   74   76
# 12  潘英迪   59   67  72   77   68
# 13  張雅芬   90   75  97   79   84
# 14  陳凱翔   79   92  85   50   55
# 15  黃佩芬   71   60  54   76   93
# 16  陳得映   84   97  82   97   61
# 17  張凱妮   73  100  71   92   56
# 18  高智超   63   79  73   81   86
# 19  鞠冠宇   74   94  94   66   96
# 20  黃淑芬   66   79  75   89   96
# 21  張婕妤   90   56  80   56   85
# 22  蘇凡菁   51   62  99   71   78
# 23  賴苑禾   68   54  78   87   91
# 24  馮芳如   62   55  80   59   93
# 25  余宗儒   90   55  83   97   68
# 26  林思賢   91   67  77   98   51
# 27  謝南慧   90   59  90   75   58
# 28  王人仰   55   68  69   75   65
# 29  王展人  100   83  77   67   78
# 30  林佳蓉   61   51  74   62  100
# 31  孫火清   83   79  96   73   60
# 32  李佳彥   94   61  76   99   55
# 33  李彥伸   87   88  73   86   64
# 34  張軒宸   75   58  84   97   63
# 35  吳欣書  100   81  79   78   78
# 36  蔡嘉音   62   97  58   62   53
# 37  黃偉剛   81   88  80   76  100
# 38  林俊翔   81   51  59   72   74
# 39  錢欣潔   86   59  66   93   56
# 40  楊火帆   63   75  58   82   52
# 41  簡佳樺   65   81  92   57   98
# 42  黃奎紹   77   89  69   66   81
# 43  李佳彥   67   80  93   55   53
# 44  張彥博   77   63  99   58   80
# 45  林希啟   52   61  68   53   61
# 46  林向鈺   82   50  95   94   93
# 47  張天亨   92   80  61   54   81
# 48  洪阿惠   97   65  84   55   75
# 49  劉耿琦   57   59  73   72   53
# 50  賴又琦   74   89  89   72   79

# %%
sum_Seriex = students_df["國文"]+students_df["英文"]+students_df["數學"]+students_df["地理"]+students_df["歷史"]
# Out:
# 學號
# 1     431
# 2     402
# 3     395
# 4     370
# 5     391
# 6     348
# 7     373
# 8     380
# 9     425
# 10    398
# 11    358
# 12    343
# 13    425
# 14    361
# 15    354
# 16    421
# 17    392
# 18    382
# 19    424
# 20    405
# 21    367
# 22    361
# 23    378
# 24    349
# 25    393
# 26    384
# 27    372
# 28    332
# 29    405
# 30    348
# 31    391
# 32    385
# 33    398
# 34    377
# 35    416
# 36    332
# 37    425
# 38    337
# 39    360
# 40    330
# 41    393
# 42    382
# 43    348
# 44    377
# 45    295
# 46    414
# 47    368
# 48    376
# 49    314
# 50    403
# dtype: int64
